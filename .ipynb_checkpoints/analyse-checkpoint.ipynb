# %%
import os
import glob
import librosa
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, LSTM
from keras.layers import TimeDistributed 
import librosa.display
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# %%
audio, sr = librosa.load('TESS Toronto emotional speech set data\\OAF_happy\\OAF_whip_happy.wav')

# Afficher l'onde audio
plt.figure(figsize=(10, 6))
librosa.display.waveshow(audio, sr=sr)
plt.title('Visualisation de l\'onde sonore')
plt.xlabel('Temps (en secondes)')
plt.ylabel('Amplitude')
plt.show()

# %%
S = librosa.stft(audio)  # Transformation de Fourier courte
D = librosa.amplitude_to_db(abs(S))  # Conversion en dB

# Visualisation du spectrogramme
plt.figure(figsize=(10, 6))
librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogramme')
plt.show()

# %%
import os
import glob
import librosa
import numpy as np
                
def extract_features(file_path):
    audio, sr = librosa.load(file_path, res_type='kaiser_fast')
    features = np.mean(librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=13).T, axis=0)
    return features

data = []
labels = []

for folder_name in os.listdir("TESS Toronto emotional speech set data"):

    folder_path = os.path.join("TESS Toronto emotional speech set data", folder_name)

    for file_path in glob.glob(os.path.join(folder_path, '*.wav')):
        features = extract_features(file_path)
        data.append(features)
        labels.append(folder_name)

# %%
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)
X_train, X_test, y_train, y_test = train_test_split(data, labels_encoded, test_size=0.2, random_state=42)

X_train = np.array(X_train)[:, np.newaxis, :]
X_test = np.array(X_test)[:, np.newaxis, :]

model = Sequential()
model.add(TimeDistributed(Dense(256, activation='relu'), input_shape=(1, X_train.shape[2])))
model.add(Dropout(0.5))
model.add(LSTM(128))
model.add(Dropout(0.5))
model.add(Dense(len(label_encoder.classes_), activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

loss, accuracy = model.evaluate(X_test, y_test)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# C:\Users\hibnc\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.0789 - loss: 2.8423 - val_accuracy: 0.0250 - val_loss: 2.6898
# Epoch 2/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.0747 - loss: 2.7023 - val_accuracy: 0.1429 - val_loss: 2.5815
# Epoch 3/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.0728 - loss: 2.6952 - val_accuracy: 0.0732 - val_loss: 2.6220
# Epoch 4/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.0762 - loss: 2.6845 - val_accuracy: 0.1018 - val_loss: 2.6002
# Epoch 5/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1003 - loss: 2.6212 - val_accuracy: 0.1232 - val_loss: 2.5266
# Epoch 6/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1039 - loss: 2.6142 - val_accuracy: 0.1250 - val_loss: 2.5080
# Epoch 7/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1115 - loss: 2.5562 - val_accuracy: 0.1554 - val_loss: 2.4474
# Epoch 8/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1353 - loss: 2.5006 - val_accuracy: 0.1518 - val_loss: 2.3024
# Epoch 9/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1509 - loss: 2.4006 - val_accuracy: 0.2411 - val_loss: 2.1761
# Epoch 10/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1773 - loss: 2.2922 - val_accuracy: 0.2268 - val_loss: 2.0918
# Epoch 11/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1939 - loss: 2.2001 - val_accuracy: 0.2232 - val_loss: 2.0255
# Epoch 12/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2163 - loss: 2.1242 - val_accuracy: 0.2446 - val_loss: 1.9475
# Epoch 13/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2503 - loss: 2.0272 - val_accuracy: 0.3589 - val_loss: 1.8302
# Epoch 14/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2589 - loss: 1.9627 - val_accuracy: 0.4500 - val_loss: 1.6765
# Epoch 15/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3132 - loss: 1.8310 - val_accuracy: 0.4464 - val_loss: 1.5879
# Epoch 16/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3651 - loss: 1.7259 - val_accuracy: 0.6411 - val_loss: 1.4292
# Epoch 17/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4228 - loss: 1.5749 - val_accuracy: 0.5643 - val_loss: 1.3180
# Epoch 18/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4312 - loss: 1.5006 - val_accuracy: 0.6964 - val_loss: 1.2181
# Epoch 19/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4810 - loss: 1.4027 - val_accuracy: 0.6589 - val_loss: 1.1061
# Epoch 20/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5314 - loss: 1.2818 - val_accuracy: 0.7464 - val_loss: 0.9793
# Epoch 21/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5550 - loss: 1.1794 - val_accuracy: 0.7482 - val_loss: 0.8774
# Epoch 22/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6355 - loss: 1.0754 - val_accuracy: 0.8232 - val_loss: 0.7700
# Epoch 23/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6187 - loss: 1.0262 - val_accuracy: 0.7946 - val_loss: 0.7044
# Epoch 24/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6749 - loss: 0.9057 - val_accuracy: 0.8643 - val_loss: 0.6036
# Epoch 25/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7199 - loss: 0.8120 - val_accuracy: 0.8571 - val_loss: 0.5280
# Epoch 26/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7256 - loss: 0.7843 - val_accuracy: 0.8786 - val_loss: 0.4608
# Epoch 27/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7541 - loss: 0.7064 - val_accuracy: 0.8821 - val_loss: 0.4218
# Epoch 28/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7571 - loss: 0.7058 - val_accuracy: 0.8946 - val_loss: 0.3805
# Epoch 29/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7780 - loss: 0.6434 - val_accuracy: 0.8839 - val_loss: 0.3825
# Epoch 30/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7678 - loss: 0.6305 - val_accuracy: 0.8946 - val_loss: 0.3411
# Epoch 31/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8025 - loss: 0.5870 - val_accuracy: 0.9071 - val_loss: 0.3247
# Epoch 32/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8172 - loss: 0.5530 - val_accuracy: 0.8982 - val_loss: 0.3074
# Epoch 33/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7933 - loss: 0.5867 - val_accuracy: 0.9089 - val_loss: 0.2952
# Epoch 34/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8114 - loss: 0.5301 - val_accuracy: 0.8893 - val_loss: 0.2865
# Epoch 35/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8327 - loss: 0.5023 - val_accuracy: 0.9000 - val_loss: 0.2864
# Epoch 36/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8137 - loss: 0.4967 - val_accuracy: 0.9107 - val_loss: 0.2664
# Epoch 37/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8223 - loss: 0.4678 - val_accuracy: 0.9107 - val_loss: 0.2661
# Epoch 38/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8554 - loss: 0.4456 - val_accuracy: 0.8964 - val_loss: 0.2887
# Epoch 39/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8537 - loss: 0.4446 - val_accuracy: 0.9143 - val_loss: 0.2418
# Epoch 40/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8516 - loss: 0.4442 - val_accuracy: 0.9214 - val_loss: 0.2298
# Epoch 41/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8528 - loss: 0.4233 - val_accuracy: 0.9196 - val_loss: 0.2335
# Epoch 42/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8492 - loss: 0.4260 - val_accuracy: 0.9107 - val_loss: 0.2540
# Epoch 43/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8674 - loss: 0.3900 - val_accuracy: 0.9143 - val_loss: 0.2542
# Epoch 44/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8492 - loss: 0.4239 - val_accuracy: 0.9143 - val_loss: 0.2321
# Epoch 45/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8614 - loss: 0.4103 - val_accuracy: 0.9071 - val_loss: 0.2672
# Epoch 46/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8837 - loss: 0.3638 - val_accuracy: 0.9268 - val_loss: 0.2084
# Epoch 47/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8536 - loss: 0.4211 - val_accuracy: 0.9411 - val_loss: 0.2021
# Epoch 48/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8692 - loss: 0.3616 - val_accuracy: 0.9179 - val_loss: 0.2207
# Epoch 49/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8682 - loss: 0.3767 - val_accuracy: 0.9268 - val_loss: 0.2121
# Epoch 50/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8720 - loss: 0.3594 - val_accuracy: 0.9196 - val_loss: 0.2104
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9120 - loss: 0.2214
# Test loss: 0.2104390561580658
# Test accuracy: 0.9196428656578064

# %%
def predict_emotion(audio_file):
    features = extract_features(audio_file)
    features = features[np.newaxis, np.newaxis, :]  
    print("Features shape:", features.shape)
    print("Features:", features)

    predicted_probabilities = model.predict(features)
    print("Predicted probabilities shape:", predicted_probabilities.shape)
    print("Predicted probabilities:", predicted_probabilities)

    predicted_label_index = np.argmax(predicted_probabilities)
    print("Predicted label index:", predicted_label_index)

    predicted_emotion = label_encoder.classes_[predicted_label_index]
    print("Predicted emotion:", predicted_emotion)
    print(label_encoder.classes_)

    # Emotion mapping for TESS dataset
    emotion_mapping = {
        'YAF_angry': 'ANGRY',
        'YAF_disgust': 'DISGUST',
        'YAF_fear': 'FEAR',
        'YAF_happy': 'HAPPY',
        'YAF_neutral': 'NEUTRAL',
        'YAF_pleasant_surprised': 'SURPRISED',
        'YAF_sad': 'SAD',
        'OAF_angry': 'ANGRY',
        'OAF_disgust': 'DISGUST',
        'OAF_Fear': 'FEAR',
        'OAF_happy': 'HAPPY',
        'OAF_neutral': 'NEUTRAL',
        'OAF_Pleasant_surprised': 'SURPRISED',
        'OAF_Sad': 'SAD',
    }


    recognizable_emotion = emotion_mapping.get(predicted_emotion)
    return recognizable_emotion

# %%
model.save('model.keras')
